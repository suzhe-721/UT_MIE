# %%
import pandas as pd
import numpy as np

# %%
response = pd.read_csv("/Users/suzhewu/Desktop/MIE1624/Assignment2/clean_kaggle_data_2022.csv",sep = ',')
response
# Out:
# /Users/suzhewu/Library/Python/3.8/lib/python/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Duration (in seconds)                           Q2  \
# 0     Duration (in seconds)  What is your age (# years)?
# 1                       851                        55-59
# 2                       501                        30-34
# 3                       787                          70+
# 4                      1132                        40-44
# ...                     ...                          ...
# 8132                    540                        40-44
# 8133                    603                        35-39
# 8134                    557                        40-44
# 8135                    860                        25-29
# 8136                    597                        35-39
#
# ...

# %%
response[response['']]
# Out:
#        Q29_Encoded
# count  8136.000000
# mean      3.760570
# std       4.356735
# min       0.000000
# 25%       0.000000
# 50%       2.000000
# 75%       7.000000
# max      14.000000
